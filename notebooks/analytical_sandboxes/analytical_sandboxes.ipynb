# %%
import os
import sys
sys.path.append('../')
os.chdir('../')

# %%
import pandas as pd
import duck_db_helper
import duckdb

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
conn = duckdb.connect('../data/analytical_sandboxes/analytical_sandbox_zone.db')
tables = duck_db_helper.get_tables(conn)
df_list = []
df_list_names = []
for table_name in tables: 
    df = conn.sql(f"SELECT * FROM \"{table_name}\";").df()
    df_list.append(df)
    df_list_names.append(table_name)
conn.close()

# %%
df = df_list[0]

# %%
df.head()
# Out:
#         team_x opp_team_name  was_home               name position  assists  bonus  bps  clean_sheets  creativity  element  goals_conceded  goals_scored  ict_index  influence  minutes  own_goals  penalties_missed  penalties_saved  yellow_cards  red_cards  round  saves  selected  threat  total_points  value  FTHG  FTAG FTR  AvgH  AvgD  AvgA   PRESS WDIR  WSPD  CLOUD  TEMP  TDEW
# 0  Southampton         Leeds         1          Che Adams      FWD        0      0    6             0        13.5      411               2             0        2.2        5.2       90          0                 0                0             0          0      2      0     53680       3             2     64     2     2   D  2.32  3.51   3.1  1015.6   NW   3.0    0.0  16.4  11.1
# 1  Southampton         Leeds         1        Roméo Lavia      MID        0      0   10             0        11.2      321               2             0        2.1        9.6       90          0                 0                0             0          0      2      0     35569       0             2     45     2     2   D  2.32  3.51   3.1  1015.6   NW   3.0    0.0  16.4  11.1
# 2  Southampton         Leeds         1  Joe Ayodele-Aribo      MID        0      1   23             0         2.1      512               0             1        9.5       39.2       29          0                 0                0             0          0      2      0     54303      54             7     55     2     2   D  2.32  3.51   3.1  1015.6   NW   3.0    0.0  16.4  11.1
# 3  Southampton         Leeds         1   Stuart Armstrong      MID        0      0    5             0        17.4      405               2             0        4.2        1.4       60          0                 0                0             0          0      2      0     10063      23             2     50     2     2   D  2.32  3.51   3.1  1015.6   NW   3.0    0.0  16.4  11.1
# 4  Southampton         Leeds         1    Mohammed Salisu      DEF        0      0    6             0         0.7      420               2             0        2.0       19.6       90          0                 0                0             1          0      2      0     14622       0             0     45     2     2   D  2.32  3.51   3.1  1015.6   NW   3.0    0.0  16.4  11.1

# %%
df.describe()
# Out:
#           was_home      assists        bonus          bps  clean_sheets   creativity      element  goals_conceded  goals_scored    ict_index    influence     minutes    own_goals  penalties_missed  penalties_saved  yellow_cards    red_cards        round        saves      selected       threat  total_points        value         FTHG         FTAG         AvgH         AvgD         AvgA        PRESS         WSPD        CLOUD         TEMP         TDEW
# count  7305.000000  7305.000000  7305.000000  7305.000000   7305.000000  7305.000000  7305.000000     7305.000000   7305.000000  7305.000000  7305.000000  7305.00000  7305.000000       7305.000000      7305.000000   7305.000000  7305.000000  7305.000000  7305.000000  7.305000e+03  7305.000000   7305.000000  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000
