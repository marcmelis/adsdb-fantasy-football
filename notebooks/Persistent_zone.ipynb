# %%
import os
import glob
from datetime import date

# %%
os.chdir('../data/landing/temporal')

# %%
for filename in glob.glob('*.*'):
  print(f"Moving {filename}")
  filebase, fileextension = filename.split(".")
  os.rename(os.path.join(os.getcwd(), filename),
            os.path.join(os.getcwd(), '../persistent/', f'{filebase}_{date.today()}.{fileextension}'))
# Out:
# Moving cleaned_merged_seasons.csv
# Moving football-data_2223.csv
# Moving master_team_list.csv
# Moving Metoffice_01_22.pdf
# Moving Metoffice_01_23.pdf
# Moving Metoffice_02_22.pdf
# Moving Metoffice_02_23.pdf
# Moving Metoffice_03_22.pdf
# Moving Metoffice_03_23.pdf
# Moving Metoffice_04_22.pdf
# Moving Metoffice_04_23.pdf
# Moving Metoffice_05_22.pdf
# Moving Metoffice_05_23.pdf
# Moving Metoffice_06_22.pdf
# Moving Metoffice_06_23.pdf
# Moving Metoffice_07_22.pdf
# Moving Metoffice_07_23.pdf
# Moving Metoffice_08_22.pdf
# Moving Metoffice_08_23.pdf
# Moving Metoffice_09_22.pdf
# Moving Metoffice_10_22.pdf
# Moving Metoffice_11_22.pdf
# Moving Metoffice_12_22.pdf
# Moving README.md
